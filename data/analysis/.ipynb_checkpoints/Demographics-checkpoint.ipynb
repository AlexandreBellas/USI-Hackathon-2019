# %% [markdown]
# # Init

# %%
import os; import pandas as pd; import numpy  as np
from pandas.tseries.offsets import *
import statsmodels.formula.api as smf

# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Demographics

# %%
def read_quarterly_data(file_name):
    path = "../data/city_of_lugano/demographics/"
    dfs = []
    for year in np.arange(2008, 2019):
        for quarter in np.arange(1, 5):
            df = pd.read_json(path+"{0}/{1}/".format(year, quarter)+file_name+'.json')
            df['year'] = year
            df['quarter'] = quarter
            df['yq'] = pd.datetime(year,quarter*3-2,1)
            dfs.append(df)

    df = pd.concat(dfs)
    return df

# %%
df = read_quarterly_data('q_quartieri')
df.rename({'Quartierenome':'nei'}, axis=1, inplace=True)
df = df.set_index(['nei','yq'])

# %%
fig, ax1 = plt.subplots(1,1, figsize=(10,5))
df.groupby(['yq'])['TotaleAbitantiCurr'].sum().plot(ax=ax1, marker='o');

# %%
neis = df.groupby(['nei'])['TotaleAbitantiCurr'].max().sort_values()
big_neis = neis[neis > 1000].index[::-1]

fig, ax1 = plt.subplots(1,1, figsize=(16,8))
neis = df.index.get_level_values(0).unique()
for nei in big_neis:
    df.xs(nei)['TotaleAbitantiCurr'].plot(ax=ax1, marker='.', label=nei);
    ax1.set_title("")
    ax1.xaxis.set_label_text("");
    ax1.yaxis.set_label_text("");
    ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax1.grid()
    plt.tight_layout();

# %%
df = read_quarterly_data('q_pop_soggiornanti')
df.head()

# %% [markdown]
# ## Other Datasets

# %%
ail = pd.read_csv("/Users/abramo/Desktop/usi_hackathon_data/data/ail/colonnine.csv")
ail.head()
# Out:
#    ChargingStationId                   ChargingStationName  \
# 0               1949  AIL - N2 - 06 - PARCHEGGIO AEROPORTO
# 1               2865         AIL - N2 - 23 - VIA INDUSTRIE
# 2               1946         AIL - N2 - 03 - STRADA REGINA
# 3               3010            AIL - P1 - 38 - VIA MULINI
# 4               2113          AIL - N2 - 15 - VIA MAROGGIA
#
#                                          Description    Paese  \
# 0                                  Ricarica gratuita     Agno
# 1  Tariffa di stazionamento (07:00 - 22:00): - du...   Bedano
# 2  Tariffa di stazionamento (07:00 - 22:00): - du...  Bioggio
# 3  Tariffa di stazionamento (07:00 - 22:00): - du...  Bioggio
# 4  Tariffa di stazionamento (07:00 - 22:00): - du...  Bissone
#
#                                      Stazione           X           Y  \
# 0  AIL - N2 - 06 - PARCHEGGIO AEROPORTO, Agno         NaN         NaN
# 1       AIL - N2 - 23 - VIA INDUSTRIE, Bedano  714540.305  101094.698
# 2      AIL - N2 - 03 - STRADA REGINA, Bioggio  713778.841   96855.316
# 3         AIL - P1 - 38 - VIA MULINI, Bioggio  713928.632   96680.165
# 4       AIL - N2 - 15 - VIA MAROGGIA, Bissone  718452.250   89731.114
#
#       osservazioni GIS
# 0  Non presente in GIS
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
ail2 = pd.read_csv("/Users/abramo/Desktop/usi_hackathon_data/data/ail/dati_ricariche_auto_elettriche_v1.csv")
ail2.head()
# Out:
#    ChargeLogId       UserId  anno BeginDate BeginHour   EndDate EndHour  \
# 0       150745  Sconosciuto  2017  01.01.17     10:30  01.01.17   10:32
# 1       150776  Sconosciuto  2017  01.01.17     14:50  01.01.17   15:51
# 2       150814  Sconosciuto  2017  01.01.17     19:40  01.01.17   21:34
# 3       150860  Sconosciuto  2017  01.02.17     12:18  01.02.17   13:15
# 4       150873  Sconosciuto  2017  01.02.17     14:50  01.02.17   14:52
#
#    Duration Durata ore  PowerConsumption      ...       Currency  \
# 0       130      00:02                23      ...            CHF
# 1      3681      01:01             16742      ...            CHF
# 2      6784      01:54             20413      ...            CHF
# 3      3457      00:57             10154      ...            CHF
# 4       121      00:02                 0      ...            CHF
#
#   TransactionType  ChargingStationId             ChargingStationName  \
# 0         Anderer               1946   AIL - N2 - 03 - STRADA REGINA
# 1         Anderer               1874  AIL - N2 - 02 - PIAZZA BROCCHI
# 2         Anderer               1946   AIL - N2 - 03 - STRADA REGINA
# 3         Anderer               1874  AIL - N2 - 02 - PIAZZA BROCCHI
# 4         Anderer               1946   AIL - N2 - 03 - STRADA REGINA
#
#         Paese                                    Stazione      Plug  \
# 0     Bioggio      AIL - N2 - 03 - STRADA REGINA, Bioggio    Destra
# 1  Montagnola  AIL - N2 - 02 - PIAZZA BROCCHI, Montagnola  Sinistra
# 2     Bioggio      AIL - N2 - 03 - STRADA REGINA, Bioggio    Destra
# 3  Montagnola  AIL - N2 - 02 - PIAZZA BROCCHI, Montagnola  Sinistra
# 4     Bioggio      AIL - N2 - 03 - STRADA REGINA, Bioggio  Sinistra
#
#            PlugType UserOperatorName UserOperatorId
# 0         Mode1_T23              NaN            NaN
# 1  Mode3_Type2_Plug              NaN            NaN
# 2  Mode3_Type2_Plug              NaN            NaN
# 3  Mode3_Type2_Plug              NaN            NaN
# 4         Mode1_T23              NaN            NaN
#
# [5 rows x 28 columns]

# %%
meteo = pd.read_csv("/Users/abramo/Desktop/usi_hackathon_data/data/meteo_suisse/Dati-meteo_Lugano.csv")
meteo.head()
# Out:
#          Data e ora  Temp. [°C]  Prec. [mm]        Data    Ora
# 0  01.10.2018 00:00        14.8         0.0  01.10.2018  00:00
# 1  01.10.2018 00:10        14.6         0.0  01.10.2018  00:10
# 2  01.10.2018 00:20        15.6         0.0  01.10.2018  00:20
# 3  01.10.2018 00:30        16.3         0.0  01.10.2018  00:30
# 4  01.10.2018 00:40        16.2         0.0  01.10.2018  00:40

# %%
bikes = pd.read_csv("/Users/abramo/Desktop/usi_hackathon_data/data/publibike/station_number_of_loans.csv")
bikes.head()
# Out:
#    Fahrt: Name Station - VON
# 0      2290666     Viganello
# 1      2298843     Viganello
# 2      2300216     Viganello
# 3      2303174     Viganello
# 4      2304140     Viganello

# %%
boats = pd.read_csv("/Users/abramo/Desktop/usi_hackathon_data/data/societa_navigazione_lugano/SNL_Data_Passeggeri_Giornaliera.csv", parse_dates=['Data'])
fig, ax1 = plt.subplots(1,1, figsize=(10,5))
boats.set_index('Data').plot(ax=ax1);

# %%
poll = pd.read_csv("/Users/abramo/Desktop/usi_hackathon_data/data/ufam/lugano_air_pollution.csv", sep=';', parse_dates=['data'])
fig, ax1 = plt.subplots(1,1, figsize=(10,5))
poll.set_index('data').plot(ax=ax1);
