# %% [markdown]
# # SNL - Società Navigazione Lugano
# ## Data about passengers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path = "societa_navigazione_lugano/SNL_Data_Passeggeri_Giornaliera.csv"

# %%
df = pd.read_csv(path, sep=',')

df.columns = ['Data', 'Passeggeri', 'Ore di Navigazione', 'KM Navigata']

# %%
df.head()
# Out:
#          Data  Passeggeri  Ore di Navigazione  KM Navigata
# 0  01/01/2018          66                6.53         61.3
# 1  01/02/2018         302                6.53         61.3
# 2  01/03/2018          67                6.53         61.3
# 3  01/04/2018          82                6.53         61.3
# 4  01/05/2018          56                6.53         61.3

# %%
df.plot()

# %%
df['Passeggeri'].hist(bins = 25)

# %%
df['KM Navigata'].hist(bin = )
